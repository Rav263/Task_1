# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img1 = cv2.imread('1.jpg')

# %%
plt.imshow(img1)

# %%
#imggr = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(imggr)

# %%
w, h = imggr.shape
w = 32 / w
h = 32 / h
print (w)
print (h)

imgscale = cv2.resize(imggr, None, fx=h,  fy=w, interpolation=cv2.INTER_CUBIC)
# Out:
# 0.064
# 0.064

# %%
plt.imshow(imgscale, 'gray')

# %%
imgscfl = np.float32(imgscale) / 255.0

dct = cv2.dct(imgscfl)

# %%
dctres = [[dct[x][y] for y in range(0, 8)] for x in range(0, 8)]

# %%
plt.imshow(dctres)

# %%
mid = 0
for x in range(0, 8):
    for y in range(0, 8):
        if x == 0 and y == 0: 
            continue
        mid += dctres[x][y]

# %%
mid /= 63
print(mid)
# Out:
# 0.0481609706019

# %%
dctbin = [[0 if dctres[x][y] < mid else 1 for y in range(0, 8)] for x in range(0, 8)]

# %%
plt.imshow(dctbin,'gray')

# %%
hash = 0;
for x in dctbin:
    for y in x:
        hash += y
        hash <<= 1

# %%
print (hex(hash))
# Out:
# 0x1e871078c43178790
